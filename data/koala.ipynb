# %%
import pandas as pd

df = pd.read_csv('koala-survey-sightings-data.csv')

df
# Out:
#       SurveyArea           LGA BushlandOrUrban     Methodology        Date  \
# 0    Koala Coast    Logan City        Bushland  Strip-transect  18/11/2010
# 1    Koala Coast    Logan City        Bushland  Strip-transect  18/11/2010
# 2    Koala Coast  Redland City        Bushland  Strip-transect  13/12/2010
# 3    Koala Coast  Redland City        Bushland  Strip-transect  13/12/2010
# 4    Koala Coast  Redland City        Bushland  Strip-transect  13/12/2010
# ..           ...           ...             ...             ...         ...
# 644        Noosa         Noosa        Bushland  Strip-transect  24/07/2013
# 645        Noosa         Noosa        Bushland  Strip-transect  27/09/2013
# 646        Noosa         Noosa        Bushland  Strip-transect  16/10/2013
# 647        Noosa         Noosa        Bushland  Strip-transect  19/11/2013
# 648        Noosa         Noosa           Urban     All-of-area  15/09/2013
#
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Date'],df['HeightOfKoalaInTree_m'])
