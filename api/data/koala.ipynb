# %%
import pandas as pd

df = pd.read_csv('koala-survey-sightings-data.csv', encoding='utf-8', parse_dates=[['Date', 'Time']])

df.dropna(subset=['HeightOfKoalaInTree_m', 'HeightOfTree_m'], inplace=True)
# Drop entries recorded at the exact same time
df.drop_duplicates(subset = ["Date_Time"], inplace=True)
# Calculate the percentage of the tree the Koala has climbed
df['PercentageHeightClimbed'] = df['HeightOfKoalaInTree_m'] / df['HeightOfTree_m']
df
# Out:
#               Date_Time   SurveyArea           LGA BushlandOrUrban  \
# 0   2010-11-18 12:55:00  Koala Coast    Logan City        Bushland
# 1   2010-11-18 17:00:00  Koala Coast    Logan City        Bushland
# 2   2010-12-13 10:20:00  Koala Coast  Redland City        Bushland
# 3   2010-12-13 13:05:00  Koala Coast  Redland City        Bushland
# 5   2010-12-13 15:10:00  Koala Coast  Redland City        Bushland
# ..                  ...          ...           ...             ...
# 642 2013-06-27 10:00:00        Noosa         Noosa        Bushland
# 643 2013-07-17 14:45:00        Noosa         Noosa        Bushland
# 644 2013-07-24 13:00:00        Noosa         Noosa        Bushland
# 645 2013-09-27 09:55:00        Noosa         Noosa        Bushland
# 647 2013-11-19 15:20:00        Noosa         Noosa        Bushland
#
#         Methodology   TransectID  Year  SurveyNumber  SiteNumber  \
# 0    Strip-transect  201000111.0  2010            20           1
# 1    Strip-transect  201000113.0  2010            20           1
# 2    Strip-transect  201000201.0  2010            20           2
# 3    Strip-transect  201000204.0  2010            20           2
# 5    Strip-transect  201000205.0  2010            20           2
# ..              ...          ...   ...           ...         ...
# 642  Strip-transect  201360401.0  2013            23         604
# 643  Strip-transect  201360505.1  2013            23         605
# 644  Strip-transect  201360512.0  2013            23         605
# 645  Strip-transect  201360806.0  2013            23         608
# 647  Strip-transect  201361102.0  2013            23         611
#
#                                            SiteName  ...  Eastings  Northings  \
# 0                                       Daisy Hill   ...  514876.0  6945396.0
# 1                                       Daisy Hill   ...  515153.0  6945857.0
# 2                                    Point Halloran  ...  529510.0  6950407.0
# 3                                    Point Halloran  ...  529297.0  6950453.0
# 5                                    Point Halloran  ...  529235.0  6950699.0
# ..                                              ...  ...       ...        ...
# 642           Noosa National Park: Eenie Creek Road  ...  505375.0  7078058.0
# 643           Noosa National Park: Headland Section  ...  509815.0  7082000.0
# 644           Noosa National Park: Headland Section  ...  509579.0  7081047.0
# 645  Tewantin National Park: Lake MacDonald Section  ...  493353.0  7082854.0
# 647                 Symplocos Environmental Reserve  ...  489684.0  7085851.0
#
#                                   TreeSpecies HeightOfKoalaInTree_m  \
# 0                                   E. carnea                  12.0
# 1                               E. microcorys                  22.0
# 2                          Alphitonia excelsa                   9.0
# 3                     Malaleuca quinquenervia                   9.0
# 5                             E. tereticornis                  12.0
# ..                                        ...                   ...
# 642  E. maculata (which is now C. citriodora)                   6.0
# 643                           E. tereticornis                  19.0
# 644                           E. siderophloia                  17.0
# 645                             E. resinifera                  22.0
# 647                   Malaleuca quinquenervia                   8.0
#
#     HeightOfTree_m     DBH_cm  CrownSize_m  CrownDensity_percentage  \
# 0             15.0       25.9          6.0                     45.0
# 1             24.0       70.7         12.0                     60.0
# 2             14.0       41.1         10.0                     60.0
# 3             12.0       17.4          4.0                     65.0
# 5             16.0       41.8         11.0                     55.0
# ..             ...        ...          ...                      ...
# 642           12.0  19.9/20.2          5.0                     45.0
# 643           21.0         66         12.0                     60.0
# 644           20.0       49.1         11.0                     60.0
# 645           28.0         38          6.0                     75.0
# 647           11.0       18.4          3.0                     70.0
#
#     OldTransectNumber PercentageHeightClimbed
# 0                  11                0.800000
# 1                  13                0.916667
# 2                   1                0.642857
# 3                   4                0.750000
# 5                   5                0.750000
# ..                ...                     ...
# 642                 1                0.500000
# 643                 5                0.904762
# 644                12                0.850000
# 645                 6                0.785714
# 647                 2                0.727273
#
# [377 rows x 31 columns]

# %%
df[['Date_Time', 'PercentageHeightClimbed']].sort_values(by=['Date_Time'])
# Out:
#               Date_Time  PercentageHeightClimbed
# 20  2010-02-12 13:55:00                 0.500000
# 21  2010-02-12 14:40:00                 0.538462
# 101 2010-03-11 10:25:00                 0.666667
# 102 2010-03-11 13:18:00                 0.875000
# 103 2010-03-11 14:20:00                 0.705882
# ..                  ...                      ...
# 568 2013-12-16 15:10:00                 0.900000
# 569 2013-12-18 09:05:00                 0.888889
# 570 2013-12-18 09:30:00                 0.700000
# 571 2013-12-18 09:40:00                 0.818182
# 572 2013-12-18 11:10:00                 0.800000
#
# [377 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,3)
plt.scatter(df['Date_Time'],df['PercentageHeightClimbed'])
plt.ylabel("Percentage of tree climbed")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
